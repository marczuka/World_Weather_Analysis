# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citypy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-90.000, high=90.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
coordinates[150]
# Out:
# (-30.327715846237865, -26.409942132671546)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 650

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval      ")
print("------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        try:
            city_rain = city_weather["rain"]["3h"]
            # Converting mm value to inches
            city_rain = city_rain/25.4
            print(f"The rain amount in {city} is {city_rain: .3f} inches.")
        except:
            city_rain = 0.000
            pass
        try:
            city_snow = city_weather["snow"]["3h"]
            # Converting mm value to inches
            city_snow = city_snow/25.4
            print(f"The snow amount in {city} is {city_snow: .3f} inches.")
        except:
            city_snow = 0
            pass
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_description,
                         "Rain inches (last 3 hrs)": city_rain,
                         "Snow inches (last 3 hrs)": city_snow})
    # If an error is esperienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    
    # Add 1 to the record count.
    record_count += 1
    
# Indicate that Data Loading is complete.
print("--------------------------------")
print("Data Retrieval Complete         ")
print("--------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | ostrovnoy
# Processing Record 2 of Set 1 | shubarkuduk
# The snow amount in shubarkuduk is  0.022 inches.
# Processing Record 3 of Set 1 | henderson
# Processing Record 4 of Set 1 | puerto ayora
# The rain amount in puerto ayora is  0.027 inches.
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | kargil
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | larsnes
# The snow amount in larsnes is  0.035 inches.
# Processing Record 11 of Set 1 | toledo
# Processing Record 12 of Set 1 | proddatur
# Processing Record 13 of Set 1 | necochea
# Processing Record 14 of Set 1 | kambove
# Processing Record 15 of Set 1 | narsaq
# The snow amount in narsaq is  0.094 inches.
# Processing Record 16 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 1 | tyukhtet
# Processing Record 18 of Set 1 | krasnoborsk
# Processing Record 19 of Set 1 | havoysund
# Processing Record 20 of Set 1 | cidreira
# Processing Record 21 of Set 1 | dikson
# The snow amount in dikson is  0.020 inches.
# Processing Record 22 of Set 1 | neftcala
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | presidencia roque saenz pena
# Processing Record 25 of Set 1 | saint anthony
# Processing Record 26 of Set 1 | valparaiso
# Processing Record 27 of Set 1 | viedma
# Processing Record 28 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 1 | alencon
# Processing Record 32 of Set 1 | muros
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | hithadhoo
# The rain amount in hithadhoo is  0.007 inches.
# Processing Record 35 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 1 | witu
# Processing Record 37 of Set 1 | dingle
# The rain amount in dingle is  0.025 inches.
# Processing Record 38 of Set 1 | mombasa
# Processing Record 39 of Set 1 | washington
# Processing Record 40 of Set 1 | kibaya
# Processing Record 41 of Set 1 | najran
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | longyearbyen
# Processing Record 45 of Set 1 | marzuq
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | penzance
# Processing Record 48 of Set 1 | southampton
# Processing Record 49 of Set 1 | jumla
# Processing Record 50 of Set 1 | vila velha
# Processing Record 1 of Set 2 | sabirabad
# Processing Record 2 of Set 2 | talnakh
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | padang
# Processing Record 5 of Set 2 | ust-ishim
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | lebu
# Processing Record 8 of Set 2 | lukovetskiy
# Processing Record 9 of Set 2 | carpinis
# The rain amount in carpinis is  0.010 inches.
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | marawi
# Processing Record 12 of Set 2 | kudahuvadhoo
# Processing Record 13 of Set 2 | zaozerne
# The rain amount in zaozerne is  0.025 inches.
# Processing Record 14 of Set 2 | bud
# Processing Record 15 of Set 2 | dharchula
# Processing Record 16 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 2 | mehamn
# The snow amount in mehamn is  0.005 inches.
# Processing Record 18 of Set 2 | qandala
# Processing Record 19 of Set 2 | utete
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | sao miguel do araguaia
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | ayagoz
# Processing Record 25 of Set 2 | harrisonburg
# Processing Record 26 of Set 2 | codrington
# Processing Record 27 of Set 2 | mafeteng
# Processing Record 28 of Set 2 | owando
# Processing Record 29 of Set 2 | victoria
# Processing Record 30 of Set 2 | bambous virieux
# Processing Record 31 of Set 2 | skagen
# Processing Record 32 of Set 2 | ugoofaaru
# The rain amount in ugoofaaru is  0.010 inches.
# Processing Record 33 of Set 2 | vila franca do campo
# Processing Record 34 of Set 2 | cabedelo
# Processing Record 35 of Set 2 | agsu
# City not found. Skipping...
# Processing Record 36 of Set 2 | upernavik
# Processing Record 37 of Set 2 | clyde river
# Processing Record 38 of Set 2 | calabar
# Processing Record 39 of Set 2 | lumeje
# The rain amount in lumeje is  0.025 inches.
# Processing Record 40 of Set 2 | dulce nombre de culmi
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | laguna
# Processing Record 43 of Set 2 | sovetskiy
# Processing Record 44 of Set 2 | saldanha
# Processing Record 45 of Set 2 | araguacu
# Processing Record 46 of Set 2 | devrek
# Processing Record 47 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 2 | santa isabel do rio negro
# Processing Record 49 of Set 2 | husavik
# The snow amount in husavik is  0.035 inches.
# Processing Record 50 of Set 2 | port hawkesbury
# Processing Record 1 of Set 3 | castro
# Processing Record 2 of Set 3 | urucara
# Processing Record 3 of Set 3 | mocuba
# Processing Record 4 of Set 3 | nepalganj
# City not found. Skipping...
# Processing Record 5 of Set 3 | mwandiga
# Processing Record 6 of Set 3 | krasnoarmeyskiy
# The rain amount in krasnoarmeyskiy is  0.012 inches.
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | vastervik
# City not found. Skipping...
# Processing Record 9 of Set 3 | pangoa
# Processing Record 10 of Set 3 | edd
# Processing Record 11 of Set 3 | namibe
# Processing Record 12 of Set 3 | zaraza
# Processing Record 13 of Set 3 | saint george
# Processing Record 14 of Set 3 | palmeiras de goias
# Processing Record 15 of Set 3 | stratford-upon-avon
# The rain amount in stratford-upon-avon is  0.035 inches.
# Processing Record 16 of Set 3 | akureyri
# The snow amount in akureyri is  0.005 inches.
# Processing Record 17 of Set 3 | luderitz
# Processing Record 18 of Set 3 | sao joao da barra
# Processing Record 19 of Set 3 | santiago
# Processing Record 20 of Set 3 | harper
# Processing Record 21 of Set 3 | miragoane
# The rain amount in miragoane is  0.032 inches.
# Processing Record 22 of Set 3 | huambo
# Processing Record 23 of Set 3 | moose factory
# Processing Record 24 of Set 3 | topchikha
# Processing Record 25 of Set 3 | krasnyy luch
# The rain amount in krasnyy luch is  0.059 inches.
# Processing Record 26 of Set 3 | paamiut
# The snow amount in paamiut is  0.010 inches.
# Processing Record 27 of Set 3 | havre-saint-pierre
# Processing Record 28 of Set 3 | port elizabeth
# Processing Record 29 of Set 3 | tocopilla
# Processing Record 30 of Set 3 | kristallopiyi
# City not found. Skipping...
# Processing Record 31 of Set 3 | port blair
# Processing Record 32 of Set 3 | trinidad
# Processing Record 33 of Set 3 | cayenne
# Processing Record 34 of Set 3 | do gonbadan
# Processing Record 35 of Set 3 | farah
# Processing Record 36 of Set 3 | kattivakkam
# Processing Record 37 of Set 3 | chuy
# Processing Record 38 of Set 3 | taipu
# Processing Record 39 of Set 3 | santa cruz do rio pardo
# Processing Record 40 of Set 3 | cicero dantas
# Processing Record 41 of Set 3 | burgeo
# Processing Record 42 of Set 3 | boende
# Processing Record 43 of Set 3 | kinango
# Processing Record 44 of Set 3 | souillac
# Processing Record 45 of Set 3 | sheltozero
# Processing Record 46 of Set 3 | zaranj
# Processing Record 47 of Set 3 | maceio
# Processing Record 48 of Set 3 | itaueira
# Processing Record 49 of Set 3 | hambantota
# Processing Record 50 of Set 3 | georgetown
# Processing Record 1 of Set 4 | goderich
# Processing Record 2 of Set 4 | itapicuru
# Processing Record 3 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 4 of Set 4 | santiago del estero
# Processing Record 5 of Set 4 | blind river
# Processing Record 6 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 4 | hatillo
# Processing Record 8 of Set 4 | macia
# The rain amount in macia is  0.012 inches.
# Processing Record 9 of Set 4 | miranorte
# City not found. Skipping...
# Processing Record 10 of Set 4 | oum hadjer
# Processing Record 11 of Set 4 | kralendijk
# Processing Record 12 of Set 4 | marathon
# Processing Record 13 of Set 4 | derzhavinsk
# Processing Record 14 of Set 4 | saint-pierre
# Processing Record 15 of Set 4 | santa rosa
# Processing Record 16 of Set 4 | klokkarvik
# City not found. Skipping...
# Processing Record 17 of Set 4 | kaka
# Processing Record 18 of Set 4 | gat
# Processing Record 19 of Set 4 | asifabad
# Processing Record 20 of Set 4 | rio gallegos
# Processing Record 21 of Set 4 | cumana
# Processing Record 22 of Set 4 | lodja
# Processing Record 23 of Set 4 | benghazi
# Processing Record 24 of Set 4 | hamilton
# Processing Record 25 of Set 4 | sao filipe
# Processing Record 26 of Set 4 | itarema
# Processing Record 27 of Set 4 | san ramon
# Processing Record 28 of Set 4 | paracuru
# Processing Record 29 of Set 4 | aksarka
# Processing Record 30 of Set 4 | ilulissat
# Processing Record 31 of Set 4 | ormond beach
# Processing Record 32 of Set 4 | ancud
# Processing Record 33 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 4 | birao
# Processing Record 35 of Set 4 | mazagao
# Processing Record 36 of Set 4 | coquimbo
# Processing Record 37 of Set 4 | mar del plata
# Processing Record 38 of Set 4 | bubaque
# Processing Record 39 of Set 4 | praia da vitoria
# Processing Record 40 of Set 4 | maun
# Processing Record 41 of Set 4 | buncrana
# The snow amount in buncrana is  0.224 inches.
# Processing Record 42 of Set 4 | krasnofarfornyy
# The snow amount in krasnofarfornyy is  0.005 inches.
# Processing Record 43 of Set 4 | amapa
# Processing Record 44 of Set 4 | beira
# Processing Record 45 of Set 4 | wukari
# Processing Record 46 of Set 4 | dudinka
# Processing Record 47 of Set 4 | doha
# Processing Record 48 of Set 4 | toro
# Processing Record 49 of Set 4 | vardo
# The snow amount in vardo is  0.010 inches.
# Processing Record 50 of Set 4 | ginda
# Processing Record 1 of Set 5 | balkhash
# Processing Record 2 of Set 5 | qunduz
# Processing Record 3 of Set 5 | caravelas
# The rain amount in caravelas is  0.076 inches.
# Processing Record 4 of Set 5 | olafsvik
# The snow amount in olafsvik is  0.089 inches.
# Processing Record 5 of Set 5 | umm kaddadah
# Processing Record 6 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 5 | puerto ayacucho
# Processing Record 8 of Set 5 | zandvoort
# Processing Record 9 of Set 5 | hofn
# The snow amount in hofn is  0.015 inches.
# Processing Record 10 of Set 5 | kalmunai
# The rain amount in kalmunai is  0.005 inches.
# Processing Record 11 of Set 5 | terekli-mekteb
# Processing Record 12 of Set 5 | sao felix do xingu
# Processing Record 13 of Set 5 | saint-augustin
# Processing Record 14 of Set 5 | mandaguacu
# Processing Record 15 of Set 5 | synya
# The snow amount in synya is  0.012 inches.
# Processing Record 16 of Set 5 | raudeberg
# The snow amount in raudeberg is  0.012 inches.
# Processing Record 17 of Set 5 | leeds
# The snow amount in leeds is  0.032 inches.
# Processing Record 18 of Set 5 | rafsanjan
# Processing Record 19 of Set 5 | nanortalik
# The snow amount in nanortalik is  0.037 inches.
# Processing Record 20 of Set 5 | zhezkazgan
# Processing Record 21 of Set 5 | mafinga
# Processing Record 22 of Set 5 | yanam
# Processing Record 23 of Set 5 | kalghatgi
# Processing Record 24 of Set 5 | tacuarembo
# Processing Record 25 of Set 5 | valdivia
# Processing Record 26 of Set 5 | bathsheba
# Processing Record 27 of Set 5 | takestan
# Processing Record 28 of Set 5 | kaoma
# The rain amount in kaoma is  0.104 inches.
# Processing Record 29 of Set 5 | margate
# Processing Record 30 of Set 5 | saquena
# Processing Record 31 of Set 5 | tanout
# Processing Record 32 of Set 5 | andilamena
# Processing Record 33 of Set 5 | canto do buriti
# Processing Record 34 of Set 5 | weligama
# Processing Record 35 of Set 5 | lima
# Processing Record 36 of Set 5 | beloha
# Processing Record 37 of Set 5 | normandin
# Processing Record 38 of Set 5 | gao
# Processing Record 39 of Set 5 | nieuw amsterdam
# Processing Record 40 of Set 5 | miracema do tocantins
# Processing Record 41 of Set 5 | biltine
# Processing Record 42 of Set 5 | kautokeino
# Processing Record 43 of Set 5 | salinas
# Processing Record 44 of Set 5 | jumilla
# Processing Record 45 of Set 5 | anloga
# Processing Record 46 of Set 5 | tabou
# Processing Record 47 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 5 | adrar
# Processing Record 50 of Set 5 | honningsvag
# The snow amount in honningsvag is  0.030 inches.
# Processing Record 1 of Set 6 | mao
# Processing Record 2 of Set 6 | waw
# Processing Record 3 of Set 6 | yefimovskiy
# City not found. Skipping...
# Processing Record 4 of Set 6 | shumikha
# Processing Record 5 of Set 6 | grindavik
# Processing Record 6 of Set 6 | pushkar
# Processing Record 7 of Set 6 | rosetta
# Processing Record 8 of Set 6 | cherepovets
# The snow amount in cherepovets is  0.030 inches.
# Processing Record 9 of Set 6 | makat
# The rain amount in makat is  0.025 inches.
# Processing Record 10 of Set 6 | chalette-sur-loing
# Processing Record 11 of Set 6 | kamenka
# Processing Record 12 of Set 6 | kayanga
# The rain amount in kayanga is  0.020 inches.
# Processing Record 13 of Set 6 | uruguaiana
# Processing Record 14 of Set 6 | mandera
# Processing Record 15 of Set 6 | emba
# Processing Record 16 of Set 6 | mecca
# Processing Record 17 of Set 6 | tres arroyos
# Processing Record 18 of Set 6 | sao jose da coroa grande
# The rain amount in sao jose da coroa grande is  0.007 inches.
# Processing Record 19 of Set 6 | scarborough
# Processing Record 20 of Set 6 | camana
# Processing Record 21 of Set 6 | vagur
# Processing Record 22 of Set 6 | kruisfontein
# Processing Record 23 of Set 6 | jurbarkas
# Processing Record 24 of Set 6 | kasongo-lunda
# Processing Record 25 of Set 6 | visnes
# The rain amount in visnes is  0.020 inches.
# Processing Record 26 of Set 6 | antalaha
# The rain amount in antalaha is  0.037 inches.
# Processing Record 27 of Set 6 | killybegs
# The rain amount in killybegs is  0.401 inches.
# Processing Record 28 of Set 6 | vyartsilya
# Processing Record 29 of Set 6 | birjand
# Processing Record 30 of Set 6 | guatire
# The rain amount in guatire is  0.010 inches.
# Processing Record 31 of Set 6 | port-gentil
# Processing Record 32 of Set 6 | oistins
# Processing Record 33 of Set 6 | marienburg
# Processing Record 34 of Set 6 | ciro marina
# Processing Record 35 of Set 6 | bandarbeyla
# Processing Record 36 of Set 6 | nouadhibou
# Processing Record 37 of Set 6 | severnoye
# Processing Record 38 of Set 6 | westport
# Processing Record 39 of Set 6 | klaksvik
# Processing Record 40 of Set 6 | abu samrah
# Processing Record 41 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 42 of Set 6 | havelock
# Processing Record 43 of Set 6 | mayumba
# Processing Record 44 of Set 6 | lokosovo
# Processing Record 45 of Set 6 | huarmey
# Processing Record 46 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 47 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 6 | ust-kulom
# The snow amount in ust-kulom is  0.025 inches.
# Processing Record 49 of Set 6 | sorland
# The snow amount in sorland is  0.015 inches.
# Processing Record 50 of Set 6 | nouakchott
# Processing Record 1 of Set 7 | san jose
# Processing Record 2 of Set 7 | cockburn town
# Processing Record 3 of Set 7 | inta
# Processing Record 4 of Set 7 | marystown
# Processing Record 5 of Set 7 | kostomuksha
# Processing Record 6 of Set 7 | tunceli
# Processing Record 7 of Set 7 | talara
# Processing Record 8 of Set 7 | sabang
# Processing Record 9 of Set 7 | dor marunt
# Processing Record 10 of Set 7 | iqaluit
# Processing Record 11 of Set 7 | glencoe
# Processing Record 12 of Set 7 | sur
# Processing Record 13 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 15 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 16 of Set 7 | salalah
# Processing Record 17 of Set 7 | luena
# The rain amount in luena is  0.104 inches.
# Processing Record 18 of Set 7 | saint-georges
# Processing Record 19 of Set 7 | basingstoke
# Processing Record 20 of Set 7 | henties bay
# Processing Record 21 of Set 7 | lubango
# Processing Record 22 of Set 7 | wawa
# Processing Record 23 of Set 7 | susangerd
# Processing Record 24 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 25 of Set 7 | chapais
# Processing Record 26 of Set 7 | abha
# Processing Record 27 of Set 7 | narsipatnam
# Processing Record 28 of Set 7 | ambo
# The rain amount in ambo is  0.005 inches.
# Processing Record 29 of Set 7 | salta
# Processing Record 30 of Set 7 | nizhniy baskunchak
# Processing Record 31 of Set 7 | portree
# Processing Record 32 of Set 7 | tabulbah
# City not found. Skipping...
# Processing Record 33 of Set 7 | yarkovo
# Processing Record 34 of Set 7 | junqueiro
# Processing Record 35 of Set 7 | zdvinsk
# Processing Record 36 of Set 7 | ierapetra
# Processing Record 37 of Set 7 | batangafo
# Processing Record 38 of Set 7 | dhidhdhoo
# Processing Record 39 of Set 7 | palma
# Processing Record 40 of Set 7 | kimovsk
# Processing Record 41 of Set 7 | shupiyan
# Processing Record 42 of Set 7 | monroe
# Processing Record 43 of Set 7 | upata
# Processing Record 44 of Set 7 | ampanihy
# Processing Record 45 of Set 7 | kedrovyy
# Processing Record 46 of Set 7 | ilo
# Processing Record 47 of Set 7 | ushtobe
# Processing Record 48 of Set 7 | kalemie
# The rain amount in kalemie is  0.030 inches.
# Processing Record 49 of Set 7 | bardiyah
# The rain amount in bardiyah is  0.027 inches.
# Processing Record 50 of Set 7 | boca do acre
# Processing Record 1 of Set 8 | desaguadero
# The rain amount in desaguadero is  0.106 inches.
# Processing Record 2 of Set 8 | bandiagara
# Processing Record 3 of Set 8 | nieuw nickerie
# Processing Record 4 of Set 8 | sokoni
# Processing Record 5 of Set 8 | rio grande
# Processing Record 6 of Set 8 | kikwit
# Processing Record 7 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 8 of Set 8 | kolokani
# Processing Record 9 of Set 8 | ventspils
# Processing Record 10 of Set 8 | depalpur
# Processing Record 11 of Set 8 | saint-leu
# Processing Record 12 of Set 8 | wad madani
# Processing Record 13 of Set 8 | maykain
# City not found. Skipping...
# Processing Record 14 of Set 8 | grande-riviere
# City not found. Skipping...
# Processing Record 15 of Set 8 | hun
# Processing Record 16 of Set 8 | berlevag
# The snow amount in berlevag is  0.005 inches.
# Processing Record 17 of Set 8 | san joaquin
# The rain amount in san joaquin is  0.005 inches.
# Processing Record 18 of Set 8 | damietta
# The rain amount in damietta is  0.094 inches.
# Processing Record 19 of Set 8 | petauke
# The rain amount in petauke is  0.153 inches.
# Processing Record 20 of Set 8 | charlestown
# Processing Record 21 of Set 8 | diamantino
# The rain amount in diamantino is  0.143 inches.
# Processing Record 22 of Set 8 | grootfontein
# Processing Record 23 of Set 8 | bara
# Processing Record 24 of Set 8 | kanniyakumari
# Processing Record 25 of Set 8 | tabuk
# Processing Record 26 of Set 8 | kavaratti
# Processing Record 27 of Set 8 | plast
# Processing Record 28 of Set 8 | coihaique
# Processing Record 29 of Set 8 | skjervoy
# The snow amount in skjervoy is  0.160 inches.
# Processing Record 30 of Set 8 | saryozek
# Processing Record 31 of Set 8 | orumiyeh
# Processing Record 32 of Set 8 | chinhoyi
# The rain amount in chinhoyi is  0.143 inches.
# Processing Record 33 of Set 8 | kulhudhuffushi
# Processing Record 34 of Set 8 | kashi
# Processing Record 35 of Set 8 | chipinge
# The rain amount in chipinge is  0.069 inches.
# Processing Record 36 of Set 8 | duayaw nkwanta
# Processing Record 37 of Set 8 | pisco
# Processing Record 38 of Set 8 | rudraprayag
# Processing Record 39 of Set 8 | mwene-ditu
# Processing Record 40 of Set 8 | sainte-rose
# Processing Record 41 of Set 8 | neokhorion
# Processing Record 42 of Set 8 | fort beaufort
# Processing Record 43 of Set 8 | vytegra
# The snow amount in vytegra is  0.035 inches.
# Processing Record 44 of Set 8 | bengkulu
# Processing Record 45 of Set 8 | revda
# Processing Record 46 of Set 8 | marsabit
# Processing Record 47 of Set 8 | alcantara
# Processing Record 48 of Set 8 | mishkino
# Processing Record 49 of Set 8 | dutlwe
# Processing Record 50 of Set 8 | arak
# Processing Record 1 of Set 9 | porbandar
# Processing Record 2 of Set 9 | yashkul
# Processing Record 3 of Set 9 | palmas
# Processing Record 4 of Set 9 | santander
# Processing Record 5 of Set 9 | pangnirtung
# Processing Record 6 of Set 9 | voznesenye
# The snow amount in voznesenye is  0.020 inches.
# Processing Record 7 of Set 9 | yazman
# Processing Record 8 of Set 9 | touros
# Processing Record 9 of Set 9 | taltal
# Processing Record 10 of Set 9 | lubao
# Processing Record 11 of Set 9 | moiyabana
# City not found. Skipping...
# Processing Record 12 of Set 9 | nosy varika
# Processing Record 13 of Set 9 | belchatow
# Processing Record 14 of Set 9 | shahpura
# Processing Record 15 of Set 9 | tambul
# City not found. Skipping...
# Processing Record 16 of Set 9 | maragogi
# The rain amount in maragogi is  0.007 inches.
# Processing Record 17 of Set 9 | trincomalee
# The rain amount in trincomalee is  0.007 inches.
# Processing Record 18 of Set 9 | sereflikochisar
# Processing Record 19 of Set 9 | sambava
# Processing Record 20 of Set 9 | krasnyy yar
# Processing Record 21 of Set 9 | bereda
# Processing Record 22 of Set 9 | sadovyy
# Processing Record 23 of Set 9 | besancon
# Processing Record 24 of Set 9 | ajaccio
# Processing Record 25 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 26 of Set 9 | qaqortoq
# The snow amount in qaqortoq is  0.052 inches.
# Processing Record 27 of Set 9 | walvis bay
# Processing Record 28 of Set 9 | carutapera
# Processing Record 29 of Set 9 | katsina
# Processing Record 30 of Set 9 | corumba
# Processing Record 31 of Set 9 | terrace bay
# Processing Record 32 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 33 of Set 9 | oktyabrskiy
# The snow amount in oktyabrskiy is  0.017 inches.
# Processing Record 34 of Set 9 | kibala
# Processing Record 35 of Set 9 | thompson
# Processing Record 36 of Set 9 | oriximina
# Processing Record 37 of Set 9 | san matias
# Processing Record 38 of Set 9 | cap malheureux
# Processing Record 39 of Set 9 | robat karim
# Processing Record 40 of Set 9 | lyuban
# Processing Record 41 of Set 9 | brekstad
# Processing Record 42 of Set 9 | santa helena de goias
# The rain amount in santa helena de goias is  0.391 inches.
# Processing Record 43 of Set 9 | masallatah
# Processing Record 44 of Set 9 | grand gaube
# Processing Record 45 of Set 9 | novoagansk
# The snow amount in novoagansk is  0.010 inches.
# Processing Record 46 of Set 9 | kemin
# Processing Record 47 of Set 9 | roura
# Processing Record 48 of Set 9 | burica
# City not found. Skipping...
# Processing Record 49 of Set 9 | ulagan
# The snow amount in ulagan is  0.007 inches.
# Processing Record 50 of Set 9 | pitimbu
# Processing Record 1 of Set 10 | acarau
# Processing Record 2 of Set 10 | aksu
# Processing Record 3 of Set 10 | joshimath
# Processing Record 4 of Set 10 | edgewater
# Processing Record 5 of Set 10 | desbiens
# Processing Record 6 of Set 10 | maxixe
# The rain amount in maxixe is  0.007 inches.
# Processing Record 7 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 10 | umm lajj
# Processing Record 9 of Set 10 | yabelo
# Processing Record 10 of Set 10 | takoradi
# Processing Record 11 of Set 10 | deep river
# Processing Record 12 of Set 10 | miandrivazo
# The rain amount in miandrivazo is  0.180 inches.
# Processing Record 13 of Set 10 | dire
# Processing Record 14 of Set 10 | hobyo
# Processing Record 15 of Set 10 | alappuzha
# Processing Record 16 of Set 10 | fredericton
# Processing Record 17 of Set 10 | kamyaran
# Processing Record 18 of Set 10 | opuwo
# Processing Record 19 of Set 10 | santa lucia
# Processing Record 20 of Set 10 | naryan-mar
# Processing Record 21 of Set 10 | eyl
# Processing Record 22 of Set 10 | durusu
# Processing Record 23 of Set 10 | nekhayevskiy
# Processing Record 24 of Set 10 | dawlatabad
# Processing Record 25 of Set 10 | esil
# Processing Record 26 of Set 10 | bridlington
# The rain amount in bridlington is  0.005 inches.
# Processing Record 27 of Set 10 | millau
# Processing Record 28 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 29 of Set 10 | camabatela
# Processing Record 30 of Set 10 | duda
# Processing Record 31 of Set 10 | barahona
# The rain amount in barahona is  0.061 inches.
# Processing Record 32 of Set 10 | tukrah
# The rain amount in tukrah is  0.007 inches.
# Processing Record 33 of Set 10 | sakakah
# Processing Record 34 of Set 10 | marolambo
# Processing Record 35 of Set 10 | lieksa
# Processing Record 36 of Set 10 | andrid
# Processing Record 37 of Set 10 | tougue
# Processing Record 38 of Set 10 | santa cruz de tenerife
# Processing Record 39 of Set 10 | mana
# Processing Record 40 of Set 10 | sistranda
# Processing Record 41 of Set 10 | estrela
# Processing Record 42 of Set 10 | feijo
# Processing Record 43 of Set 10 | yar-sale
# Processing Record 44 of Set 10 | galle
# Processing Record 45 of Set 10 | abapo
# Processing Record 46 of Set 10 | maravilha
# Processing Record 47 of Set 10 | pietrosita
# Processing Record 48 of Set 10 | oshkosh
# Processing Record 49 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 50 of Set 10 | williamsburg
# Processing Record 1 of Set 11 | kristiinankaupunki
# Processing Record 2 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 3 of Set 11 | geisenheim
# Processing Record 4 of Set 11 | mwinilunga
# Processing Record 5 of Set 11 | vilhena
# Processing Record 6 of Set 11 | mpika
# The rain amount in mpika is  0.035 inches.
# Processing Record 7 of Set 11 | tarnogskiy gorodok
# The snow amount in tarnogskiy gorodok is  0.005 inches.
# Processing Record 8 of Set 11 | toamasina
# Processing Record 9 of Set 11 | santa cruz
# Processing Record 10 of Set 11 | mudyuga
# City not found. Skipping...
# Processing Record 11 of Set 11 | itanhem
# The rain amount in itanhem is  0.030 inches.
# Processing Record 12 of Set 11 | san ignacio
# Processing Record 13 of Set 11 | general pico
# Processing Record 14 of Set 11 | the valley
# Processing Record 15 of Set 11 | deder
# Processing Record 16 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 17 of Set 11 | tabas
# Processing Record 18 of Set 11 | san andres
# Processing Record 19 of Set 11 | turukhansk
# The snow amount in turukhansk is  0.010 inches.
# Processing Record 20 of Set 11 | roald
# The snow amount in roald is  0.017 inches.
# Processing Record 21 of Set 11 | marsa matruh
# The rain amount in marsa matruh is  0.010 inches.
# Processing Record 22 of Set 11 | taoudenni
# Processing Record 23 of Set 11 | cururupu
# Processing Record 24 of Set 11 | caranavi
# Processing Record 25 of Set 11 | wer
# Processing Record 26 of Set 11 | tornio
# Processing Record 27 of Set 11 | marsh harbour
# Processing Record 28 of Set 11 | ambilobe
# The rain amount in ambilobe is  0.020 inches.
# Processing Record 29 of Set 11 | aswan
# Processing Record 30 of Set 11 | lichinga
# The rain amount in lichinga is  0.081 inches.
# Processing Record 31 of Set 11 | mandiana
# Processing Record 32 of Set 11 | westerland
# Processing Record 33 of Set 11 | tyup
# Processing Record 34 of Set 11 | koutiala
# Processing Record 35 of Set 11 | bodden town
# Processing Record 36 of Set 11 | sao joao batista
# Processing Record 37 of Set 11 | aligudarz
# The rain amount in aligudarz is  0.007 inches.
# Processing Record 38 of Set 11 | zlobin
# Processing Record 39 of Set 11 | nanga eboko
# Processing Record 40 of Set 11 | chokwe
# The rain amount in chokwe is  0.005 inches.
# Processing Record 41 of Set 11 | orcopampa
# The rain amount in orcopampa is  0.084 inches.
# Processing Record 42 of Set 11 | miram shah
# Processing Record 43 of Set 11 | vavozh
# The snow amount in vavozh is  0.057 inches.
# Processing Record 44 of Set 11 | quatre cocos
# Processing Record 45 of Set 11 | assen
# Processing Record 46 of Set 11 | puerto escondido
# Processing Record 47 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 11 | binga
# The rain amount in binga is  0.207 inches.
# Processing Record 49 of Set 11 | benton harbor
# Processing Record 50 of Set 11 | rognan
# Processing Record 1 of Set 12 | salcininkai
# Processing Record 2 of Set 12 | plouzane
# Processing Record 3 of Set 12 | benguela
# Processing Record 4 of Set 12 | sisimiut
# Processing Record 5 of Set 12 | dilla
# Processing Record 6 of Set 12 | salamiyah
# Processing Record 7 of Set 12 | sinnamary
# The rain amount in sinnamary is  0.005 inches.
# Processing Record 8 of Set 12 | birin
# Processing Record 9 of Set 12 | morganton
# Processing Record 10 of Set 12 | ebebiyin
# Processing Record 11 of Set 12 | apatou
# Processing Record 12 of Set 12 | paita
# Processing Record 13 of Set 12 | sao caetano de odivelas
# Processing Record 14 of Set 12 | port-cartier
# Processing Record 15 of Set 12 | sabha
# Processing Record 16 of Set 12 | wana
# Processing Record 17 of Set 12 | sompeta
# Processing Record 18 of Set 12 | tessaoua
# Processing Record 19 of Set 12 | urumqi
# Processing Record 20 of Set 12 | correntina
# Processing Record 21 of Set 12 | liverpool
# Processing Record 22 of Set 12 | bobrovka
# Processing Record 23 of Set 12 | korla
# Processing Record 24 of Set 12 | waynesboro
# Processing Record 25 of Set 12 | high rock
# Processing Record 26 of Set 12 | cervo
# Processing Record 27 of Set 12 | kasur
# Processing Record 28 of Set 12 | otjiwarongo
# The rain amount in otjiwarongo is  0.010 inches.
# Processing Record 29 of Set 12 | komatipoort
# Processing Record 30 of Set 12 | rundu
# The rain amount in rundu is  0.113 inches.
# Processing Record 31 of Set 12 | barra do garcas
# The rain amount in barra do garcas is  0.170 inches.
# Processing Record 32 of Set 12 | sabnova
# Processing Record 33 of Set 12 | grand-santi
# Processing Record 34 of Set 12 | eschwege
# Processing Record 35 of Set 12 | shache
# Processing Record 36 of Set 12 | klaebu
# Processing Record 37 of Set 12 | dhule
# Processing Record 38 of Set 12 | manaure
# Processing Record 39 of Set 12 | emet
# Processing Record 40 of Set 12 | emborion
# Processing Record 41 of Set 12 | nushki
# Processing Record 42 of Set 12 | sept-iles
# Processing Record 43 of Set 12 | kathmandu
# Processing Record 44 of Set 12 | svetlyy
# Processing Record 45 of Set 12 | ochakiv
# Processing Record 46 of Set 12 | ponta delgada
# Processing Record 47 of Set 12 | robertsport
# The rain amount in robertsport is  0.005 inches.
# Processing Record 48 of Set 12 | carbonia
# Processing Record 49 of Set 12 | aleppo
# Processing Record 50 of Set 12 | rawson
# Processing Record 1 of Set 13 | namwala
# The rain amount in namwala is  0.300 inches.
# Processing Record 2 of Set 13 | ponazyrevo
# The snow amount in ponazyrevo is  0.005 inches.
# Processing Record 3 of Set 13 | neuquen
# Processing Record 4 of Set 13 | itaituba
# Processing Record 5 of Set 13 | waupun
# Processing Record 6 of Set 13 | afua
# The rain amount in afua is  0.007 inches.
# Processing Record 7 of Set 13 | hauterive
# Processing Record 8 of Set 13 | sharjah
# Processing Record 9 of Set 13 | tarauaca
# Processing Record 10 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 11 of Set 13 | usinsk
# The snow amount in usinsk is  0.010 inches.
# Processing Record 12 of Set 13 | puerto colombia
# Processing Record 13 of Set 13 | mogadishu
# Processing Record 14 of Set 13 | praia
# Processing Record 15 of Set 13 | niquelandia
# Processing Record 16 of Set 13 | kemijarvi
# City not found. Skipping...
# Processing Record 17 of Set 13 | carnarvon
# Processing Record 18 of Set 13 | mussomeli
# Processing Record 19 of Set 13 | bressanone
# Processing Record 20 of Set 13 | puerto quijarro
# Processing Record 21 of Set 13 | jalu
# Processing Record 22 of Set 13 | kondinskoye
# Processing Record 23 of Set 13 | lesnoy
# Processing Record 24 of Set 13 | komsomolets
# Processing Record 25 of Set 13 | nazca
# Processing Record 26 of Set 13 | ouadda
# Processing Record 27 of Set 13 | lively
# Processing Record 28 of Set 13 | serenje
# The rain amount in serenje is  0.074 inches.
# Processing Record 29 of Set 13 | bondoukou
# Processing Record 30 of Set 13 | bundi
# Processing Record 31 of Set 13 | pilao arcado
# City not found. Skipping...
# Processing Record 32 of Set 13 | la asuncion
# Processing Record 33 of Set 13 | puerto narino
# Processing Record 34 of Set 13 | camocim
# Processing Record 35 of Set 13 | thessalon
# Processing Record 36 of Set 13 | nioro
# Processing Record 37 of Set 13 | carballo
# Processing Record 38 of Set 13 | garowe
# Processing Record 39 of Set 13 | omaruru
# Processing Record 40 of Set 13 | morondava
# The rain amount in morondava is  0.027 inches.
# Processing Record 41 of Set 13 | seredeyskiy
# Processing Record 42 of Set 13 | morros
# Processing Record 43 of Set 13 | olden
# The snow amount in olden is  0.015 inches.
# Processing Record 44 of Set 13 | atar
# Processing Record 45 of Set 13 | sechura
# Processing Record 46 of Set 13 | el cope
# Processing Record 47 of Set 13 | maniitsoq
# Processing Record 48 of Set 13 | buzmeyin
# Processing Record 49 of Set 13 | camacha
# Processing Record 50 of Set 13 | inirida
# --------------------------------
# Data Retrieval Complete
# --------------------------------

# %%
len(city_data)
# Out:
# 604

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(20)
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 0        Ostrovnoy      RU  2020-02-24 01:41:23  68.05   39.51     26.56
# 1      Shubarkuduk      KZ  2020-02-24 01:41:23  49.14   56.49     22.21
# 2        Henderson      US  2020-02-24 01:41:23  36.04 -114.98     64.40
# 3     Puerto Ayora      EC  2020-02-24 01:41:24  -0.74  -90.35     79.00
# 4   Saint-Philippe      RE  2020-02-24 01:41:24 -21.36   55.77     75.20
# 5        Busselton      AU  2020-02-24 01:41:24 -33.65  115.33     80.01
# 6       Bredasdorp      ZA  2020-02-24 01:41:24 -34.53   20.04     63.00
# 7           Kargil      IN  2020-02-24 01:41:24  34.57   76.10     -4.94
# 8        Mahebourg      MU  2020-02-24 01:41:25 -20.41   57.70     73.99
# 9          Larsnes      NO  2020-02-24 01:41:25  62.20    5.58     37.40
# 10          Toledo      ES  2020-02-24 01:41:25  39.83   -4.00     48.99
# 11       Proddatur      IN  2020-02-24 01:41:25  14.73   78.55     73.92
# 12        Necochea      AR  2020-02-24 01:41:25 -38.55  -58.74     64.00
# 13         Kambove      CD  2020-02-24 01:41:26 -10.88   26.60     63.01
# 14          Narsaq      GL  2020-02-24 01:41:26  60.92  -46.05     23.00
# 15        Tyukhtet      RU  2020-02-24 01:41:26  56.54   89.30     13.19
# 16     Krasnoborsk      RU  2020-02-24 01:41:27  61.56   45.93     28.02
# 17       Havoysund      NO  2020-02-24 01:41:27  71.00   24.66     33.80
# 18        Cidreira      BR  2020-02-24 01:41:27 -30.18  -50.21     72.64
# 19          Dikson      RU  2020-02-24 01:41:27  73.51   80.55     23.90
#
#     Humidity  Cloudiness  Wind Speed Current Description  \
# 0         92         100        9.40     overcast clouds
# 1         95         100       16.82          light snow
# 2         31           1        5.95           clear sky
# 3        100          88        3.00          light rain
# 4         69          19        6.93          few clouds
# 5         34         100       15.21     overcast clouds
# 6         81           0        5.82           clear sky
# 7         81           0        1.57           clear sky
# 8         94          20        3.36          few clouds
# 9         55         100       13.87          light snow
# 10        84           0        2.77           clear sky
# 11        69          99        4.81     overcast clouds
# 12        70           0       10.00           clear sky
# 13        97         100        8.12     overcast clouds
# 14        67         100       13.87                snow
# 15        94          67        2.73       broken clouds
# 16        91          67        7.09       broken clouds
# 17        80          75       13.87       broken clouds
# 18        75          15       25.12          few clouds
# 19        91         100       27.76          light snow
#
#     Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                   0.000000                  0.000000
# 1                   0.000000                  0.022047
# 2                   0.000000                  0.000000
# 3                   0.027165                  0.000000
# 4                   0.000000                  0.000000
# 5                   0.000000                  0.000000
# 6                   0.000000                  0.000000
# 7                   0.000000                  0.000000
# 8                   0.000000                  0.000000
# 9                   0.000000                  0.034646
# 10                  0.000000                  0.000000
# 11                  0.000000                  0.000000
# 12                  0.000000                  0.000000
# 13                  0.000000                  0.000000
# 14                  0.000000                  0.093701
# 15                  0.000000                  0.000000
# 16                  0.000000                  0.000000
# 17                  0.000000                  0.000000
# 18                  0.000000                  0.000000
# 19                  0.000000                  0.019685

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_challenge.csv"
# Export the City_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
cities_rain_count = len(city_data_df.loc[city_data_df["Rain inches (last 3 hrs)"] > 0])
print(f"It is or was raining in {cities_rain_count} cities withing 3 hrs.")
# Out:
# It is or was raining in 59 cities withing 3 hrs.

# %%
cities_snow_count = len(city_data_df.loc[city_data_df["Snow inches (last 3 hrs)"] > 0])
print(f"It is or was snowing in {cities_snow_count} cities withing 3 hrs.")
# Out:
# It is or was snowing in 36 cities withing 3 hrs.

# %%
city_data_df.loc[city_data_df["Rain inches (last 3 hrs)"] > 0].head(10)
# Out:
#                     City Country                 Date    Lat     Lng  \
# 3           Puerto Ayora      EC  2020-02-24 01:41:24  -0.74  -90.35
# 30             Hithadhoo      MV  2020-02-24 01:41:30  -0.60   73.08
# 32                Dingle      PH  2020-02-24 01:41:31  11.00  122.67
# 53              Carpinis      RO  2020-02-24 01:41:35  45.79   20.90
# 57              Zaozerne      UA  2020-02-24 01:41:36  45.16   33.28
# 75             Ugoofaaru      MV  2020-02-24 01:41:40   5.67   73.00
# 81                Lumeje      AO  2020-02-24 01:41:42 -11.55   20.78
# 96       Krasnoarmeyskiy      RU  2020-02-24 01:41:45  47.01   42.21
# 104  Stratford-Upon-Avon      GB  2020-02-24 01:41:47  52.19   -1.71
# 110            Miragoane      HT  2020-02-24 01:41:48  18.44  -73.09
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 3       79.00       100          88        3.00          light rain
# 30      83.39        79          78       13.49          light rain
# 32      82.51        70          89       14.38          light rain
# 53      50.00        61         100        3.36          light rain
# 57      45.46        80         100       28.74          light rain
# 75      83.16        77          54       17.81          light rain
# 81      67.17        88         100       10.96          light rain
# 96      39.00        87         100       16.51          light rain
# 104     45.00        75         100        4.70          light rain
# 110     78.44        71           0        4.07          light rain
#
#      Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 3                    0.027165                       0.0
# 30                   0.007480                       0.0
# 32                   0.024803                       0.0
# 53                   0.009843                       0.0
# 57                   0.024803                       0.0
# 75                   0.009843                       0.0
# 81                   0.024803                       0.0
# 96                   0.012205                       0.0
# 104                  0.034646                       0.0
# 110                  0.031890                       0.0
